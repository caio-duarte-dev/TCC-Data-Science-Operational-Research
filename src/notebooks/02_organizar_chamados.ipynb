# %%
import pandas as pd
from pathlib import Path

# ==============================
# Caminhos do projeto
# ==============================

BASE_DIR = Path().resolve().parent
DATA_DIR = BASE_DIR / "data"

path_chamados = DATA_DIR / "chamados.xlsx"

# ==============================
# Ordenação dos chamados
# ==============================

def ordenar_chamados(path_excel=path_chamados):
    try:
        chamados = pd.read_excel(path_excel)

        chamados['data_abertura'] = pd.to_datetime(chamados['data_abertura'])

        chamados_ordenados = chamados.sort_values(
            by=['prioridade', 'data_abertura', 'cliente'],
            ascending=[True, True, True]
        ).reset_index(drop=True)

        chamados_ordenados.to_excel(path_excel, index=False)

        return chamados_ordenados

    except FileNotFoundError:
        print(f"O arquivo {path_excel} não foi encontrado.")
        return pd.DataFrame()

# ==============================
# Execução
# ==============================

chamados_ordenados = ordenar_chamados()

display(chamados_ordenados)
# Out:
#       id     cliente     maquina           tipo_manutencao  tempo_necessario  \
# 0    147  cliente_15  maquina_10     manutencao_preventiva                 2
# 1     92  cliente_14  maquina_10     manutencao_preventiva                 2
# 2    167  cliente_19   maquina_5     manutencao_preventiva                 2
# 3     52   cliente_2   maquina_9      manutencao_corretiva                 3
# 4     14  cliente_30   maquina_4  avaliacao_do_equipamento                 1
# ..   ...         ...         ...                       ...               ...
# 195  114  cliente_15   maquina_4      manutencao_corretiva                 3
# 196   86  cliente_16   maquina_2      manutencao_corretiva                 3
# 197  146   cliente_9   maquina_8     manutencao_preventiva                 2
# 198  143   cliente_9  maquina_10     manutencao_preventiva                 2
# 199   10  cliente_25   maquina_7  avaliacao_do_equipamento                 1
#
#        prioridade data_abertura
# 0    prioridade_1    2026-01-01
# 1    prioridade_1    2026-01-04
# 2    prioridade_1    2026-01-04
# 3    prioridade_1    2026-01-04
# 4    prioridade_1    2026-01-04
# ..            ...           ...
# 195  prioridade_3    2026-04-14
# 196  prioridade_3    2026-04-17
# 197  prioridade_3    2026-04-22
# 198  prioridade_3    2026-04-25
# 199  prioridade_3    2026-04-29
#
# [200 rows x 7 columns]
