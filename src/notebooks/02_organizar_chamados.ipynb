# %%
import pandas as pd
from pathlib import Path

# ==============================
# Caminhos do projeto
# ==============================

BASE_DIR = Path().resolve().parent
DATA_DIR = BASE_DIR / "data"

path_chamados = DATA_DIR / "chamados.xlsx"

# ==============================
# Ordenação dos chamados
# ==============================

def ordenar_chamados(path_excel=path_chamados):
    try:
        chamados = pd.read_excel(path_excel)

        chamados['data_abertura'] = pd.to_datetime(chamados['data_abertura'])

        chamados_ordenados = chamados.sort_values(
            by=['prioridade', 'data_abertura', 'cliente'],
            ascending=[True, True, True]
        ).reset_index(drop=True)

        chamados_ordenados.to_excel(path_excel, index=False)

        return chamados_ordenados

    except FileNotFoundError:
        print(f"O arquivo {path_excel} não foi encontrado.")
        return pd.DataFrame()

# ==============================
# Execução
# ==============================

chamados_ordenados = ordenar_chamados()

display(chamados_ordenados)
# Out:
#       id     cliente     maquina           tipo_manutencao  tempo_necessario  \
# 0     72  cliente_22   maquina_5  avaliacao_do_equipamento                 1
# 1      9  cliente_10   maquina_6  avaliacao_do_equipamento                 1
# 2    128  cliente_12  maquina_10     manutencao_preventiva                 2
# 3     18   cliente_6   maquina_6     manutencao_preventiva                 2
# 4      3  cliente_14   maquina_3  avaliacao_do_equipamento                 1
# ..   ...         ...         ...                       ...               ...
# 195  129  cliente_13   maquina_6     manutencao_preventiva                 2
# 196   38   cliente_6   maquina_3      manutencao_corretiva                 3
# 197   64   cliente_5   maquina_8     manutencao_preventiva                 2
# 198  122   cliente_3   maquina_7     manutencao_preventiva                 2
# 199  156   cliente_1   maquina_2      manutencao_corretiva                 3
#
#        prioridade data_abertura
# 0    prioridade_1    2026-01-01
# 1    prioridade_1    2026-01-03
# 2    prioridade_1    2026-01-03
# 3    prioridade_1    2026-01-03
# 4    prioridade_1    2026-01-05
# ..            ...           ...
# 195  prioridade_3    2026-04-14
# 196  prioridade_3    2026-04-14
# 197  prioridade_3    2026-04-18
# 198  prioridade_3    2026-04-20
# 199  prioridade_3    2026-04-29
#
# [200 rows x 7 columns]
